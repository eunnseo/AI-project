# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import lightgbm

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score

from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier

# %%
# set options
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# 예측한 값으로 성능을 평가하는 함수
def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix(y_test, pred) # 오차 행렬
    accuracy = accuracy_score(y_test, pred) # 정확도
    precision = precision_score(y_test, pred) # 정밀도
    recall = recall_score(y_test, pred) # 재현율
    f1 = f1_score(y_test, pred) # F1
    roc_auc = roc_auc_score(y_test, pred_proba) # ROC-AUC
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %% [markdown]
# ### Test2

# %%
vote_df = pd.read_csv("C:\\Users\\kimsj\\OneDrive\\바탕 화면\\대학교\\git\\AI-project\\data\\train.csv", encoding="utf-8")
test_df = pd.read_csv("C:\\Users\\kimsj\\OneDrive\\바탕 화면\\대학교\\git\\AI-project\\data\\test.csv", encoding="utf-8")
# 인덱스 제거
vote_df.drop("index", axis=1, inplace=True)
test_df.drop("index", axis=1, inplace=True)

# %%
# 0값을 검사할 피처명 리스트 객체 설정
zero_features = ['education', 'engnat', 'hand', 'urban']

# tp 추가
for i in range(1, 11):
    s = 'tp' + chr(48+(i//10)) + chr(48+(i%10))
    zero_features.append(s)
    
# zero_features 리스트 내부에 저장된 개별 피처들에 대해 0값을 평균 값으로 대체
vote_df[zero_features] = vote_df[zero_features].replace(0, vote_df[zero_features].mean())

# %%
### F1 = 0.7021

# 레이블 인코딩
encoder = LabelEncoder()
encoder2 = LabelEncoder()
encoder.fit(vote_df['age_group'])
encoder2.fit(test_df['age_group'])
labels = encoder.transform(vote_df['age_group'])
labels2 = encoder2.transform(test_df['age_group'])
vote_df['age_group'] = labels
test_df['age_group'] = labels2

def get_categoty_age(age_num):
    num = age_num;
    if age_num == 0: num =7

    return num
vote_df["age_group"] = vote_df["age_group"].apply(lambda x : get_categoty_age(x))
test_df["age_group"] = vote_df["age_group"].apply(lambda x : get_categoty_age(x))

#원핫인코딩 진행
def dummy_data(data, columns) :
    for column in columns:
        data = pd.concat([data, pd.get_dummies(data[column], prefix = column)], axis=1)
        data = data.drop(column, axis=1)
    return data

dummy_columns = ['engnat', 'gender','hand', 'married', 'race', 'religion', 'urban']
vote_df = dummy_data(vote_df, dummy_columns)
test_df = dummy_data(vote_df, dummy_columns)

# feature 분리 및 학습세트/평가세트 분리
y_labels = vote_df.loc[:,'voted']
X_features = vote_df.drop('voted', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X_features, y_labels, test_size=0.2, random_state=156)


# 데이터 정규화(스케일링)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# oversampling
from imblearn.over_sampling import RandomOverSampler
over_sampler = RandomOverSampler(random_state=156)
X_train_over, y_train_over = over_sampler.fit_resample(X_train, y_train)


# 학습
evals = [(X_test, y_test)]
xgb_model = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3, objective="binary:logistic", random_state=156)
xgb_model.fit(X_train_over, y_train_over, early_stopping_rounds=100, eval_metric="logloss", eval_set=evals, verbose=True)
w_preds = xgb_model.predict(X_test)
w_pred_proba = xgb_model.predict_proba(X_test)[:,1]

get_clf_eval(y_test, w_preds, w_pred_proba)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'engnat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-fd9a8ee24087> in <module>
#      28 dummy_columns = ['engnat', 'gender','hand', 'married', 'race', 'religion', 'urban']
#      29 vote_df = dummy_data(vote_df, dummy_columns)
# ---> 30 test_df = dummy_data(vote_df, dummy_columns)
#      31
#      32 # feature 분리 및 학습세트/평가세트 분리
#
# <ipython-input-6-fd9a8ee24087> in dummy_data(data, columns)
#      22 def dummy_data(data, columns) :
#      23     for column in columns:
# ---> 24         data = pd.concat([data, pd.get_dummies(data[column], prefix = column)], axis=1)
#      25         data = data.drop(column, axis=1)
#      26     return data
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'engnat'

# %%
### 데이터 정규화(스케일링), oversampling 적용 X

# 레이블 인코딩
encoder = LabelEncoder()
encoder2 = LabelEncoder()
encoder.fit(vote_df['age_group'])
encoder2.fit(test_df['age_group'])
labels = encoder.transform(vote_df['age_group'])
labels2 = encoder.transform(test_df['age_group'])
vote_df['age_group'] = labels
test_df['age_group'] = labels2

def get_categoty_age(age_num):
    num = age_num;
    if age_num == 0: num =7

    return num
vote_df["age_group"] = vote_df["age_group"].apply(lambda x : get_categoty_age(x))
test_df["age_group"] = vote_df["age_group"].apply(lambda x : get_categoty_age(x))

#원핫인코딩 진행
def dummy_data(data, columns) :
    for column in columns:
        data = pd.concat([data, pd.get_dummies(data[column], prefix = column)], axis=1)
        data = data.drop(column, axis=1)
    return data

dummy_columns = ['engnat', 'gender','hand', 'married', 'race', 'religion', 'urban']
vote_df = dummy_data(vote_df, dummy_columns)
test_df = dummy_data(vote_df, dummy_columns)

# %%
# 학습
y_labels = vote_df.loc[:,'voted']
X_features = vote_df.drop('voted', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X_features, y_labels, test_size=0.2, random_state=156)

evals = [(X_test, y_test)]

xgb_model = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3, objective="binary:logistic", random_state=156)
xgb_model.fit(X_train, y_train, early_stopping_rounds=100, eval_metric="logloss", eval_set=evals, verbose=True)
w_preds = xgb_model.predict(X_test)
w_pred_proba = xgb_model.predict_proba(X_test)[:,1]

get_clf_eval(y_test, w_preds, w_pred_proba)
# Out:
# [0]	validation_0-logloss:0.67449
# [1]	validation_0-logloss:0.65909
# C:\Users\kimsj\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [2]	validation_0-logloss:0.64643
# [3]	validation_0-logloss:0.63550
# [4]	validation_0-logloss:0.62660
# [5]	validation_0-logloss:0.61908
# [6]	validation_0-logloss:0.61268
# [7]	validation_0-logloss:0.60686
# [8]	validation_0-logloss:0.60212
# [9]	validation_0-logloss:0.59800
# [10]	validation_0-logloss:0.59436
# [11]	validation_0-logloss:0.59130
# [12]	validation_0-logloss:0.58842
# [13]	validation_0-logloss:0.58611
# [14]	validation_0-logloss:0.58386
# [15]	validation_0-logloss:0.58191
# [16]	validation_0-logloss:0.58032
# [17]	validation_0-logloss:0.57899
# [18]	validation_0-logloss:0.57773
# [19]	validation_0-logloss:0.57665
# [20]	validation_0-logloss:0.57580
# [21]	validation_0-logloss:0.57497
# [22]	validation_0-logloss:0.57421
# [23]	validation_0-logloss:0.57358
# [24]	validation_0-logloss:0.57291
# [25]	validation_0-logloss:0.57231
# [26]	validation_0-logloss:0.57188
# [27]	validation_0-logloss:0.57133
# [28]	validation_0-logloss:0.57097
# [29]	validation_0-logloss:0.57019
# [30]	validation_0-logloss:0.56983
# [31]	validation_0-logloss:0.56963
# [32]	validation_0-logloss:0.56927
# [33]	validation_0-logloss:0.56893
# [34]	validation_0-logloss:0.56868
# [35]	validation_0-logloss:0.56857
# [36]	validation_0-logloss:0.56833
# [37]	validation_0-logloss:0.56810
# [38]	validation_0-logloss:0.56794
# [39]	validation_0-logloss:0.56768
# [40]	validation_0-logloss:0.56750
# [41]	validation_0-logloss:0.56736
# [42]	validation_0-logloss:0.56719
# [43]	validation_0-logloss:0.56703
# [44]	validation_0-logloss:0.56692
# [45]	validation_0-logloss:0.56681
# [46]	validation_0-logloss:0.56673
# [47]	validation_0-logloss:0.56657
# [48]	validation_0-logloss:0.56645
# [49]	validation_0-logloss:0.56639
# [50]	validation_0-logloss:0.56639
# [51]	validation_0-logloss:0.56630
# [52]	validation_0-logloss:0.56616
# [53]	validation_0-logloss:0.56619
# [54]	validation_0-logloss:0.56609
# [55]	validation_0-logloss:0.56612
# [56]	validation_0-logloss:0.56608
# [57]	validation_0-logloss:0.56598
# [58]	validation_0-logloss:0.56591
# [59]	validation_0-logloss:0.56574
# [60]	validation_0-logloss:0.56564
# [61]	validation_0-logloss:0.56553
# [62]	validation_0-logloss:0.56548
# [63]	validation_0-logloss:0.56552
# [64]	validation_0-logloss:0.56551
# [65]	validation_0-logloss:0.56541
# [66]	validation_0-logloss:0.56544
# [67]	validation_0-logloss:0.56549
# [68]	validation_0-logloss:0.56544
# [69]	validation_0-logloss:0.56542
# [70]	validation_0-logloss:0.56535
# [71]	validation_0-logloss:0.56534
# [72]	validation_0-logloss:0.56534
# [73]	validation_0-logloss:0.56523
# [74]	validation_0-logloss:0.56525
# [75]	validation_0-logloss:0.56517
# [76]	validation_0-logloss:0.56510
# [77]	validation_0-logloss:0.56515
# [78]	validation_0-logloss:0.56506
# [79]	validation_0-logloss:0.56503
# [80]	validation_0-logloss:0.56502
# [81]	validation_0-logloss:0.56500
# [82]	validation_0-logloss:0.56499
# [83]	validation_0-logloss:0.56509
# [84]	validation_0-logloss:0.56507
# [85]	validation_0-logloss:0.56496
# [86]	validation_0-logloss:0.56495
# [87]	validation_0-logloss:0.56475
# [88]	validation_0-logloss:0.56471
# [89]	validation_0-logloss:0.56468
# [90]	validation_0-logloss:0.56463
# [91]	validation_0-logloss:0.56458
# [92]	validation_0-logloss:0.56465
# [93]	validation_0-logloss:0.56463
# [94]	validation_0-logloss:0.56466
# [95]	validation_0-logloss:0.56468
# [96]	validation_0-logloss:0.56460
# [97]	validation_0-logloss:0.56455
# [98]	validation_0-logloss:0.56452
# [99]	validation_0-logloss:0.56450
# [100]	validation_0-logloss:0.56448
# [101]	validation_0-logloss:0.56448
# [102]	validation_0-logloss:0.56445
# [103]	validation_0-logloss:0.56444
# [104]	validation_0-logloss:0.56440
# [105]	validation_0-logloss:0.56440
# [106]	validation_0-logloss:0.56440
# [107]	validation_0-logloss:0.56437
# [108]	validation_0-logloss:0.56441
# [109]	validation_0-logloss:0.56437
# [110]	validation_0-logloss:0.56442
# [111]	validation_0-logloss:0.56447
# [112]	validation_0-logloss:0.56453
# [113]	validation_0-logloss:0.56450
# [114]	validation_0-logloss:0.56451
# [115]	validation_0-logloss:0.56451
# [116]	validation_0-logloss:0.56462
# [117]	validation_0-logloss:0.56467
# [118]	validation_0-logloss:0.56474
# [119]	validation_0-logloss:0.56480
# [120]	validation_0-logloss:0.56482
# [121]	validation_0-logloss:0.56490
# [122]	validation_0-logloss:0.56493
# [123]	validation_0-logloss:0.56490
# [124]	validation_0-logloss:0.56491
# [125]	validation_0-logloss:0.56483
# [126]	validation_0-logloss:0.56483
# [127]	validation_0-logloss:0.56479
# [128]	validation_0-logloss:0.56475
# [129]	validation_0-logloss:0.56477
# [130]	validation_0-logloss:0.56478
# [131]	validation_0-logloss:0.56476
# [132]	validation_0-logloss:0.56479
# [133]	validation_0-logloss:0.56475
# [134]	validation_0-logloss:0.56482
# [135]	validation_0-logloss:0.56480
# [136]	validation_0-logloss:0.56481
# [137]	validation_0-logloss:0.56489
# [138]	validation_0-logloss:0.56493
# [139]	validation_0-logloss:0.56489
# [140]	validation_0-logloss:0.56487
# [141]	validation_0-logloss:0.56482
# [142]	validation_0-logloss:0.56481
# [143]	validation_0-logloss:0.56483
# [144]	validation_0-logloss:0.56483
# [145]	validation_0-logloss:0.56486
# [146]	validation_0-logloss:0.56486
# [147]	validation_0-logloss:0.56492
# [148]	validation_0-logloss:0.56497
# [149]	validation_0-logloss:0.56502
# [150]	validation_0-logloss:0.56494
# [151]	validation_0-logloss:0.56490
# [152]	validation_0-logloss:0.56480
# [153]	validation_0-logloss:0.56484
# [154]	validation_0-logloss:0.56490
# [155]	validation_0-logloss:0.56490
# [156]	validation_0-logloss:0.56484
# [157]	validation_0-logloss:0.56484
# [158]	validation_0-logloss:0.56480
# [159]	validation_0-logloss:0.56475
# [160]	validation_0-logloss:0.56486
# [161]	validation_0-logloss:0.56484
# [162]	validation_0-logloss:0.56483
# [163]	validation_0-logloss:0.56481
# [164]	validation_0-logloss:0.56478
# [165]	validation_0-logloss:0.56481
# [166]	validation_0-logloss:0.56481
# [167]	validation_0-logloss:0.56487
# [168]	validation_0-logloss:0.56489
# [169]	validation_0-logloss:0.56492
# [170]	validation_0-logloss:0.56500
# [171]	validation_0-logloss:0.56505
# [172]	validation_0-logloss:0.56505
# [173]	validation_0-logloss:0.56504
# [174]	validation_0-logloss:0.56511
# [175]	validation_0-logloss:0.56509
# [176]	validation_0-logloss:0.56499
# [177]	validation_0-logloss:0.56503
# [178]	validation_0-logloss:0.56497
# [179]	validation_0-logloss:0.56496
# [180]	validation_0-logloss:0.56503
# [181]	validation_0-logloss:0.56505
# [182]	validation_0-logloss:0.56501
# [183]	validation_0-logloss:0.56496
# [184]	validation_0-logloss:0.56490
# [185]	validation_0-logloss:0.56480
# [186]	validation_0-logloss:0.56481
# [187]	validation_0-logloss:0.56485
# [188]	validation_0-logloss:0.56487
# [189]	validation_0-logloss:0.56485
# [190]	validation_0-logloss:0.56496
# [191]	validation_0-logloss:0.56504
# [192]	validation_0-logloss:0.56505
# [193]	validation_0-logloss:0.56502
# [194]	validation_0-logloss:0.56503
# [195]	validation_0-logloss:0.56508
# [196]	validation_0-logloss:0.56508
# [197]	validation_0-logloss:0.56504
# [198]	validation_0-logloss:0.56504
# [199]	validation_0-logloss:0.56511
# [200]	validation_0-logloss:0.56516
# [201]	validation_0-logloss:0.56509
# [202]	validation_0-logloss:0.56509
# [203]	validation_0-logloss:0.56513
# [204]	validation_0-logloss:0.56505
# [205]	validation_0-logloss:0.56515
# [206]	validation_0-logloss:0.56519
# 오차 행렬
# [[2583 1433]
#  [ 828 2441]]
# 정확도: 0.6896, 정밀도: 0.6301, 재현율: 0.7467, F1: 0.6835, AUC:0.7597
# C:\Users\kimsj\anaconda3\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
from xgboost import plot_importance
fig, ax = plt.subplots(1,1, figsize=(10,8))
plot_importance(xgb_model, ax=ax, max_num_features=20, height=0.4)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
vote_df.sample(10)
# Out:
#        QaA   QaE  QbA   QbE  QcA   QcE  QdA   QdE  QeA   QeE  QfA   QfE  QgA  \
# 3992   2.0   465  2.0  1703  4.0  1167  2.0   196  2.0   587  2.0   884  2.0
# 28001  1.0   385  5.0   458  4.0   728  1.0   432  5.0   242  1.0   460  1.0
# 22982  5.0   557  1.0  1522  2.0  2932  4.0  2347  5.0  2678  4.0  3199  5.0
# 15206  1.0   893  3.0  3276  4.0  1234  1.0  1441  3.0  1698  3.0   726  4.0
# 23236  2.0   829  5.0   857  5.0   199  1.0   660  2.0  1620  5.0   369  5.0
# 12024  1.0  1129  5.0   932  4.0   892  1.0   491  1.0   471  1.0   701  3.0
# 3165   3.0   518  1.0  2967  3.0   695  1.0  1071  4.0  1221  5.0   626  4.0
# 14263  3.0   345  1.0   470  1.0   299  3.0   416  5.0  1012  1.0   267  1.0
# 11756  1.0   540  1.0   849  5.0   444  1.0   683  1.0   939  1.0   427  1.0
# 2580   3.0   400  2.0   965  2.0   712  2.0   908  4.0  1134  2.0   453  4.0
#
#        QgE  QhA   QhE  QiA   QiE  QjA   QjE  QkA   QkE  QlA   QlE  QmA   QmE  \
# 3992   563  3.0  1033  4.0  1602  1.0  1423  5.0   668  1.0   731  4.0   826
# 28001  363  2.0   638  4.0  1714  5.0   522  5.0  1687  5.0   712  5.0   890
# 22982  949  1.0  2100  4.0  3908  2.0  2284  5.0  1306  4.0  2589  2.0  4296
# 15206  844  3.0  1581  3.0  2380  3.0  1598  3.0  1513  4.0  1452  2.0   975
# 23236  360  5.0  1588  1.0  2250  5.0   754  5.0   907  1.0  1498  5.0  1502
# 12024  641  1.0   987  1.0  1440  5.0   663  2.0  1069  5.0   671  5.0   880
# 3165   657  1.0  1088  5.0  1754  4.0  1959  5.0   764  3.0  1069  1.0  1002
# 28001                            0                          0
# 22982                            0                          0
# 15206                            0                          0
# 23236                            0                          0
# 12024                            0                          0
# 3165                             0                          0
# 14263                            0                          0
# 11756                            0                          0
# 2580                             0                          0
#
#        religion_Christian_Other  religion_Christian_Protestant  \
# 3992                          0                              0
# 28001                         0                              0
# 22982                         1                              0
# 15206                         0                              0
# 23236                         0                              0
# 12024                         0                              0
# 3165                          1                              0
# 14263                         0                              1
# 11756                         0                              1
# 2580                          0                              1
#
#        religion_Hindu  religion_Jewish  religion_Muslim  religion_Other  \
# 3992                0                0                0               0
# 28001               1                0                0               0
# 22982               0                0                0               0
# 15206               0                0                0               1
# 23236               0                0                0               0
# 12024               0                0                0               0
# 3165                0                0                0               0
# 14263               0                0                0               0
# 11756               0                0                0               0
# 2580                0                0                0               0
#
#        religion_Sikh  urban_1.0  urban_2.0  urban_2.1795744680851064  \
# 3992               0          0          1                         0
# 28001              0          0          0                         0
# 22982              0          1          0                         0
# 15206              0          0          1                         0
# 23236              0          0          0                         0
# 12024              0          0          0                         0
# 3165               0          1          0                         0
# 14263              0          0          1                         0
# 11756              0          0          1                         0
# 2580               0          0          0                         0
#
#        urban_3.0
# 3992           0
# 28001          1
# 22982          0
# 15206          0
# 23236          1
# 12024          1
# 3165           0
# 14263          0
# 11756          0
# 2580           1

# %%
#evals = [(X_test, y_test)]

xgb_model2 = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3, objective="binary:logistic", random_state=156)
xgb_model2.fit(X_train.sample(test_df.shape[0]), y_train.sample(test_df.shape[0]))
w_preds2 = xgb_model.predict(test_df)
w_pred_proba2 = xgb_model.predict_proba(test_df)[:,1]

get_clf_eval(y_test, w_preds, w_pred_proba)
# Out:
# C:\Users\kimsj\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:38:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-ff385fc01612> in <module>
#       3 xgb_model2 = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3, objective="binary:logistic", random_state=156)
#       4 xgb_model2.fit(X_train.sample(test_df.shape[0]), y_train.sample(test_df.shape[0]))
# ----> 5 w_preds2 = xgb_model.predict(test_df)
#       6 w_pred_proba2 = xgb_model.predict_proba(test_df)[:,1]
#       7
#
# ~\anaconda3\lib\site-packages\xgboost\sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1207         iteration_range: Optional[Tuple[int, int]] = None,
#    1208     ):
# -> 1209         class_probs = super().predict(
#    1210             X=X,
#    1211             output_margin=output_margin,
#
# ~\anaconda3\lib\site-packages\xgboost\sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     818         if self._can_use_inplace_predict():
#     819             try:
# --> 820                 predts = self.get_booster().inplace_predict(
#     821                     data=X,
#     822                     iteration_range=iteration_range,
#
# ~\anaconda3\lib\site-packages\xgboost\core.py in inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    1836         if validate_features:
#    1837             if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# -> 1838                 raise ValueError(
#    1839                     f"Feature shape mismatch, expected: {self.num_features()}, "
#    1840                     f"got {data.shape[0]}"
#
# ValueError: Feature shape mismatch, expected: 105, got 9107

# %% [markdown]
# ---

# %%
test_df.shape
# Out:
# (9107, 76)

# %%
import csv
f= open("test.csv", 'w', newline='')
wr = csv.writer(f)
wr.writerow(w_preds2)
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-49fbf98a6ffe> in <module>
#       2 f= open("test.csv", 'w', newline='')
#       3 wr = csv.writer(f)
# ----> 4 wr.writerow(w_preds2)
#       5 f.close()
#
# NameError: name 'w_preds2' is not defined
